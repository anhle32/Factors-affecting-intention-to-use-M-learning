# %%
import semopy
import pandas as pd
import seaborn as sns
import numpy as np
import psython as psy
import pingouin as pg
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
df=pd.read_csv('datafinal.csv')

# %%
df=df[:452]

# %%
df.tail(7)
# Out:
#      PEOU1  PEOU2  PEOU3  PEOU4  PE1  PE2  PE3  PE4  SI1  SI2  ...  PV2  PV3  \
# 445      3      3      4      4    3    4    4    3    4    3  ...    3    2
# 446      2      2      2      3    2    3    3    2    3    2  ...    3    2
# 447      2      3      3      2    1    2    2    3    3    2  ...    3    3
# 448      3      4      4      3    2    2    3    3    3    3  ...    2    3
# 449      3      4      3      3    2    2    3    2    4    3  ...    5    4
# 450      3      3      3      3    2    3    3    3    3    4  ...    4    3
# 451      3      3      3      3    3    2    3    3    2    3  ...    3    3
#
#      IU1  IU2  IU3  TR1  TR2  TR3  GENDER  YEAR
# 445    4    4    4    1    1    2       0     4
# 446    3    2    2    2    2    2       0     3
# 447    2    1    2    1    1    1       0     4
# 448    2    3    3    1    1    2       0     2
# 449    4    3    3    4    3    3       0     1
# 450    4    3    4    3    3    3       0     4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PEOU1   452 non-null    int64
#  1   PEOU2   452 non-null    int64
#  2   PEOU3   452 non-null    int64
#  3   PEOU4   452 non-null    int64
#  4   PE1     452 non-null    int64
#  5   PE2     452 non-null    int64
#  6   PE3     452 non-null    int64
#  7   PE4     452 non-null    int64
#  8   SI1     452 non-null    int64
#  9   SI2     452 non-null    int64
#  10  SI3     452 non-null    int64
#  11  FC1     452 non-null    int64
#  12  FC2     452 non-null    int64
#  13  FC3     452 non-null    int64
#  14  FC4     452 non-null    int64
#  15  HM1     452 non-null    int64
#  16  HM2     452 non-null    int64
#  17  HM3     452 non-null    int64
#  18  PV1     452 non-null    int64
#  19  PV2     452 non-null    int64
#  20  PV3     452 non-null    int64
#  21  IU1     452 non-null    int64
# ...

# %%
PEOU_scale=df[['PEOU1','PEOU2','PEOU3','PEOU4']]
PE_scale=df[['PE1','PE2','PE3','PE4']]
SI_scale=df[['SI1','SI2','SI3']]
FC_scale=df[['FC1','FC2','FC3','FC4']]
HM_scale=df[['HM1','HM2','HM3']]
PV_scale=df[['PV1','PV2','PV3']]
TR_scale=df[['TR1','TR2','TR3']]
IU_scale=df[['IU1','IU2','IU3']]

# %%
psy.cronbach_alpha_scale_if_deleted(PEOU_scale)
# Out:
# [(0.7965631583768433, array([0.764, 0.826])),
#      Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  PEOU1                   10.128319                        3.389263
#  1  PEOU2                   10.039823                        3.186881
#  2  PEOU3                   10.059735                        3.297976
#  3  PEOU4                   10.086283                        2.992539
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.605033                          0.748611
#  1                          0.606573                          0.746481
#  2                          0.566987                          0.765802
#  3                          0.656826                          0.720608  ]

# %%
psy.cronbach_alpha_scale_if_deleted(PE_scale)
# Out:
# [(0.8267377731063583, array([0.799, 0.851])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  PE1                    9.477876                        3.066028
#  1  PE2                    9.329646                        2.979784
#  2  PE3                    8.845133                        2.809666
#  3  PE4                    8.752212                        2.874164
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.639783                          0.787645
#  1                          0.647353                          0.783793
#  2                          0.709367                          0.754829
#  3                          0.618077                          0.799037  ]

# %%
psy.cronbach_alpha_scale_if_deleted(SI_scale)
# Out:
# [(0.789547054464616, array([0.754, 0.821])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  SI1                    6.219027                        1.475203
#  1  SI2                    6.696903                        1.661809
#  2  SI3                    6.269912                        1.545612
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.620496                          0.728564
#  1                          0.602005                          0.744048
#  2                          0.673389                          0.668931  ]

# %%
psy.cronbach_alpha_scale_if_deleted(FC_scale)
# Out:
# [(0.8300209139522361, array([0.803, 0.854])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  FC1                   10.199115                        3.312815
#  1  FC2                   10.212389                        3.449247
#  2  FC3                   10.241150                        3.380742
#  3  FC4                   10.245575                        3.516056
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.637268                          0.796156
#  1                          0.654979                          0.786509
#  2                          0.661765                          0.783419
#  3                          0.681029                          0.776525  ]

# %%
psy.cronbach_alpha_scale_if_deleted(HM_scale)
# Out:
# [(0.8098392906587297, array([0.777, 0.838])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  HM1                    6.774336                        1.891313
#  1  HM2                    6.783186                        1.935149
#  2  HM3                    6.756637                        1.838648
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.633738                          0.765902
#  1                          0.643583                          0.754961
#  2                          0.700441                          0.696146  ]

# %%
psy.cronbach_alpha_scale_if_deleted(PV_scale)
# Out:
# [(0.7518654813373402, array([0.709, 0.789])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  PV1                    6.783186                        1.580382
#  1  PV2                    6.725664                        1.494418
#  2  PV3                    6.743363                        1.610266
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.587232                          0.660670
#  1                          0.630467                          0.609362
#  2                          0.524880                          0.732172  ]

# %%
psy.cronbach_alpha_scale_if_deleted(TR_scale)
# Out:
# [(0.8195354579045718, array([0.789, 0.847])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  TR1                    4.811947                        2.157462
#  1  TR2                    4.637168                        2.426819
#  2  TR3                    4.413717                        3.005842
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.692642                          0.744679
#  1                          0.739430                          0.683582
#  2                          0.616794                          0.811754  ]

# %%
psy.cronbach_alpha_scale_if_deleted(IU_scale)
# Out:
# [(0.8416990593947755, array([0.815, 0.865])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  IU1                    6.772124                        2.065474
#  1  IU2                    6.738938                        2.175598
#  2  IU3                    6.798673                        2.143413
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.713495                          0.773075
#  1                          0.676230                          0.808722
#  2                          0.730424                          0.757415  ]

# %%
df1=df.drop(columns=['GENDER','YEAR','IU1','IU2','IU3'])

# %%
sns.set(rc={'figure.figsize':(20,15)})
sns.heatmap(df1.corr(),annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>

# %%
from factor_analyzer import (FactorAnalyzer,ConfirmatoryFactorAnalyzer,ModelSpecificationParser)
import matplotlib.pyplot as plt

# %%
fa=FactorAnalyzer(n_factors=7,rotation='promax')

# %%
fa.fit(df1)
# Out:
# FactorAnalyzer(n_factors=7, rotation_kwargs={})

# %%
loadings= fa.loadings_
loadings
# Out:
# array([[ 9.85577380e-02,  5.55560892e-03,  6.85858023e-01,
#          3.25808132e-02,  1.54746363e-02, -6.68940751e-02,
#          5.02515400e-02],
#        [-1.80053979e-02,  1.12049806e-02,  6.84288120e-01,
#         -7.41222575e-02,  1.61632617e-02,  4.01816989e-02,
#         -3.78126399e-02],
#        [-1.20956733e-01, -2.82978857e-04,  6.75731558e-01,
#          1.71086933e-03,  1.21326379e-02,  4.83425420e-02,
#         -3.79051293e-02],
#        [ 7.52212152e-02, -1.58648337e-02,  7.68876755e-01,
#          1.95559719e-02, -3.81837129e-02, -9.58352288e-03,
#          1.46439379e-02],
#        [ 7.24011982e-01,  2.45356035e-02,  6.39992575e-02,
#          1.88458847e-02, -5.23066661e-02, -3.95666763e-02,
#          2.33140486e-03],
#        [ 7.36334059e-01,  1.08797188e-02, -3.98848883e-02,
#         -5.33815047e-02,  6.46017917e-02, -5.01928851e-02,
#         -2.79890871e-02],
#        [ 8.44692556e-01,  2.44035266e-02, -7.11757975e-02,
# ...

# %%
ev,v=fa.get_eigenvalues()

# %%
xvals=range(1,df1.shape[1]+1)

# %%
plt.scatter(xvals,ev)
plt.plot(xvals,ev)
plt.title('Scree plot')
plt.xlabel('Factor')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
fa_loading=pd.DataFrame(loadings,index=df1.columns)
fa_loading
# Out:
#               0         1         2         3         4         5         6
# PEOU1  0.098558  0.005556  0.685858  0.032581  0.015475 -0.066894  0.050252
# PEOU2 -0.018005  0.011205  0.684288 -0.074122  0.016163  0.040182 -0.037813
# PEOU3 -0.120957 -0.000283  0.675732  0.001711  0.012133  0.048343 -0.037905
# PEOU4  0.075221 -0.015865  0.768877  0.019556 -0.038184 -0.009584  0.014644
# PE1    0.724012  0.024536  0.063999  0.018846 -0.052307 -0.039567  0.002331
# PE2    0.736334  0.010880 -0.039885 -0.053382  0.064602 -0.050193 -0.027989
# PE3    0.844693  0.024404 -0.071176 -0.031108 -0.061157  0.122218 -0.067638
# PE4    0.651204 -0.082761  0.057897  0.070720  0.072309  0.008021  0.067381
# SI1   -0.014326  0.029256 -0.014153  0.012125  0.042670  0.688147  0.026941
# SI2    0.057926  0.069472  0.028589  0.005345  0.000894  0.640095 -0.001281
# SI3   -0.015791 -0.065725  0.010708  0.005486  0.019796  0.850426  0.018265
# ...

# %%
data_loading=fa_loading.apply(lambda x: (np.where(x< 0.5,'',x)))
data_loading
# Out:
#                         0                   1                   2  \
# PEOU1                                          0.6858580229446561
# PEOU2                                          0.6842881202271904
# PEOU3                                          0.6757315582113977
# PEOU4                                          0.7688767553735375
# PE1    0.7240119821243018
# PE2    0.7363340587335206
# PE3    0.8446925564316221
# PE4    0.6512043443580272
# SI1
# SI2
# SI3
# FC1                         0.689278508285054
# FC2                         0.739327475757041
# FC3                        0.7138388075138352
# FC4                        0.8306288873163322
# HM1
# HM2
# HM3
# PV1
# PV2
# PV3
# TR1
# TR2
# TR3
#
#                         3                   4                   5  \
# PEOU1
# PEOU2
# PEOU3
# PEOU4
# PE1
# PE2
# PE3
# PE4
# SI1                                            0.6881468047120272
# SI2                                             0.640094574738506
# ...

# %%
data_loading.to_excel('loadings.xlsx')

# %%
desc='PEOU=~PEOU1+PEOU2+PEOU3+PEOU4'+'\n PE=~PE1+PE2+PE3+PE4'+'\n SI=~SI1+SI2+SI3'+'\n FC=~FC1+FC2+FC3+FC4'+'\n HM=~HM1+HM2+HM3'+'\n PV=~PV1+PV2+PV3'+'\n TR=~TR1+TR2+TR3'+'\n IU=~IU1+IU2+IU3'+'\n PEOU~~PE'+'\n PEOU~~SI'+'\n PEOU~~FC'+'\n PEOU~~HM'+'\n PEOU~~PV'+'\n PEOU~~TR'+'\n PE~~SI'+'\n PE~~FC'+'\n PE~~HM'+'\n PE~~PV'+'\n PE~~TR'+'\n SI~~FC'+'\n SI~~HM'+'\n SI~~PV'+'\n SI~~TR'+'\n FC~~HM'+'\n FC~~PV'+'\n FC~~TR'+'\n HM~~PV'+'\n HM~~TR'+'\n PV~~TR'+'\n IU~PEOU+PE+SI+FC+HM+PV+TR'

# %%
print(desc)
# Out:
# PEOU=~PEOU1+PEOU2+PEOU3+PEOU4
#  PE=~PE1+PE2+PE3+PE4
#  SI=~SI1+SI2+SI3
#  FC=~FC1+FC2+FC3+FC4
#  HM=~HM1+HM2+HM3
#  PV=~PV1+PV2+PV3
#  TR=~TR1+TR2+TR3
#  IU=~IU1+IU2+IU3
#  PEOU~~PE
#  PEOU~~SI
#  PEOU~~FC
#  PEOU~~HM
#  PEOU~~PV
#  PEOU~~TR
#  PE~~SI
#  PE~~FC
#  PE~~HM
#  PE~~PV
#  PE~~TR
#  SI~~FC
#  SI~~HM
#  SI~~PV
#  SI~~TR
#  FC~~HM
#  FC~~PV
#  FC~~TR
#  HM~~PV
#  HM~~TR
#  PV~~TR
#  IU~PEOU+PE+SI+FC+HM+PV+TR

# %%
mod = semopy.Model(desc)

# %%
df2=df.drop(columns=['GENDER','YEAR'])

# %%
res = mod.fit(df2)
print(res)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 1.252
# Number of iterations: 47
# Params: 1.068 0.955 1.220 1.043 1.206 1.097 0.900 0.995 0.950 0.983 0.931 0.978 1.114 1.039 0.845 0.972 0.658 0.905 0.982 0.050 0.091 0.084 0.123 0.032 -0.009 0.236 0.083 0.085 0.128 0.061 0.020 0.215 0.117 0.165 0.071 0.043 0.299 0.171 0.079 -0.017 0.318 0.112 0.010 0.327 0.009 0.283 0.178 0.386 0.265 0.213 0.177 0.239 0.195 0.177 0.268 0.247 0.183 0.216 0.310 0.244 0.231 0.335 0.214 0.162 0.217 0.288 0.293 0.284 0.325 0.220 0.140 0.266 0.283 0.199 0.626 0.280 0.372 0.179 0.195 0.333 0.176 0.008

# %%
sem = mod.inspect()
print(sem)
# Out:
#      lval  op   rval  Estimate  Std. Err    z-value   p-value
# 0      IU   ~   PEOU  0.280426  0.065584   4.275819  0.000019
# 1      IU   ~     PE  0.371558   0.06968   5.332362       0.0
# 2      IU   ~     SI  0.178571  0.062781   2.844336   0.00445
# 3      IU   ~     FC  0.194603  0.058906   3.303606  0.000954
# 4      IU   ~     HM  0.332872   0.07711   4.316857  0.000016
# ..    ...  ..    ...       ...       ...        ...       ...
# 85  PEOU3  ~~  PEOU3  0.324620  0.025504  12.728076       0.0
# 86  PEOU1  ~~  PEOU1  0.220209  0.019578  11.247547       0.0
# 87    SI1  ~~    SI1  0.265643  0.024425  10.876082       0.0
# 88    IU2  ~~    IU2  0.283237  0.023083  12.270492       0.0
# 89    PE1  ~~    PE1  0.199420   0.01666  11.970219       0.0
#
# [90 rows x 7 columns]

# %%
SEM=pd.DataFrame(sem)
SEM.head(7)
# Out:
#   lval op  rval  Estimate  Std. Err   z-value   p-value
# 0   IU  ~  PEOU  0.280426  0.065584  4.275819  0.000019
# 1   IU  ~    PE  0.371558   0.06968  5.332362       0.0
# 2   IU  ~    SI  0.178571  0.062781  2.844336   0.00445
# 3   IU  ~    FC  0.194603  0.058906  3.303606  0.000954
# 4   IU  ~    HM  0.332872   0.07711  4.316857  0.000016
# 5   IU  ~    PV  0.176459  0.056945  3.098751  0.001943
# 6   IU  ~    TR  0.008070  0.032415   0.24897  0.803384

# %%
SEM1=SEM[0:7]
SEM1.to_excel('sem.xlsx')

# %%
import os
os.environ['PATH'] += os.pathsep + 'C:/Program Files/Graphviz/bin'
from semopy import semplot
g_sem = semplot(mod,filename="sem.png")
g_sem

# %%
stats = semopy.calc_stats(mod)
print(stats.T)
# Out:
#                      Value
# DoF             296.000000
# DoF Baseline    351.000000
# chi2            566.080153
# chi2 p-value      0.000000
# chi2 Baseline  5417.505137
# CFI               0.946693
# GFI               0.895509
# AGFI              0.876094
# NFI               0.895509
# TLI               0.936788
# RMSEA             0.044979
# AIC             161.495221
# BIC             498.817159
# LogLik            1.252390

# %%
chi2_df=stats.chi2.values/stats.DoF.values
chi2_df
# Out:
# array([1.91243295])

# %%
import VisualizeNN as VisNN
from sklearn.neural_network import MLPRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
df2.columns
# Out:
# Index(['PEOU1', 'PEOU2', 'PEOU3', 'PEOU4', 'PE1', 'PE2', 'PE3', 'PE4', 'SI1',
#        'SI2', 'SI3', 'FC1', 'FC2', 'FC3', 'FC4', 'HM1', 'HM2', 'HM3', 'PV1',
#        'PV2', 'PV3', 'IU1', 'IU2', 'IU3', 'TR1', 'TR2', 'TR3'],
#       dtype='object')

# %%
df2['PEOU']=df2[['PEOU1', 'PEOU2', 'PEOU3', 'PEOU4']].mean(axis=1)
df2['PE']=df2[['PE1', 'PE2', 'PE3', 'PE4']].mean(axis=1)
df2['SI']=df2[['SI1',  'SI2', 'SI3']].mean(axis=1)
df2['FC']=df2[['FC1', 'FC2', 'FC3']].mean(axis=1)
df2['HM']=df2[['HM1', 'HM2', 'HM3']].mean(axis=1)
df2['PV']=df2[['PV1',  'PV2', 'PV3']].mean(axis=1)
df2['IU']=df2[['IU1', 'IU2', 'IU3']].mean(axis=1)

# %%
X=df2[['PEOU','PE','SI','FC','HM','PV']]
y=df2['IU']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1, test_size=0.2)

# %%
sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.fit_transform(X_test)

# %% [markdown]
# # Structure of ANN according to Fang and Ma (2009)

# %%
regr = MLPRegressor(hidden_layer_sizes=(3,),random_state=1, max_iter=500).fit(X_trainscaled, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
network_structure = np.hstack(([X_trainscaled.shape[1]], np.asarray(regr.hidden_layer_sizes), [1]))

# %%
network=VisNN.DrawNN(network_structure, regr.coefs_)
network.draw()

# %%
regr.coefs_
# Out:
# [array([[ 0.3833151 ,  0.14263855, -0.08829512],
#         [ 0.1526538 , -0.21743242,  0.0660169 ],
#         [-0.68302475, -0.02834501,  0.4809067 ],
#         [-0.02450635, -0.13783459,  0.10364995],
#         [ 0.02171855,  0.36396549,  0.0808556 ],
#         [ 0.39529609,  0.02850375, -0.13120052]]),
#  array([[ 0.96130836],
#         [-0.25762851],
#         [ 1.21140266]])]

# %%
y_pred = regr.predict(X_testscaled)
y_pred
# Out:
# array([3.61478265, 3.27474867, 3.98795157, 3.66569179, 3.15561946,
#        2.73614329, 3.3752324 , 3.90343512, 3.33987461, 3.58247619,
#        3.89417983, 2.67869599, 3.21252135, 3.73937838, 2.99992162,
#        4.2137421 , 3.03454497, 4.27792234, 3.67042001, 3.46684761,
#        2.73614329, 3.59305733, 4.48752452, 3.96672625, 2.0846562 ,
#        2.87585229, 2.36097411, 3.58014032, 3.43786253, 3.82618077,
#        3.58247619, 3.52520361, 3.10778926, 3.30655473, 2.84830048,
#        2.89106217, 3.22134191, 2.05638811, 3.83356813, 3.93086993,
#        3.76449166, 3.07933551, 3.76449166, 3.67235315, 2.80360577,
#        4.09443561, 3.2859573 , 3.1395818 , 3.47293511, 3.40683198,
#        2.98868014, 3.29040825, 4.00575948, 4.0056675 , 3.47293511,
#        3.53132553, 2.8388191 , 4.60089713, 4.06073037, 2.89106217,
#        3.53446259, 3.33676256, 3.34737126, 2.29531953, 2.72297766,
#        3.38644684, 3.61616328, 3.71893524, 3.03156952, 2.71026126,
# ...

# %%
df_temp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_temp.head()
# Out:
#        Actual  Predicted
# 207  4.000000   3.614783
# 383  3.000000   3.274749
# 65   4.333333   3.987952
# 197  3.000000   3.665692
# 208  3.666667   3.155619

# %%
df_temp = df_temp.head(30)
df_temp.plot(kind='bar',figsize=(10,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.42195642461114524
# Mean Squared Error: 0.26656132647966957
# Root Mean Squared Error: 0.5162957742221697

# %%
def garson(A, B):
    """
    Computes Garson's algorithm
    A = matrix of weights of input-hidden layer (rows=input & cols=hidden)
    B = vector of weights of hidden-output layer
    """
    B = np.diag(B)

    # connection weight through the different hidden node
    cw = np.dot(A, B)

    # weight through node (axis=0 is column; sum per input feature)
    cw_h = abs(cw).sum(axis=0)

    # relative contribution of input neuron to outgoing signal of each hidden neuron
    # sum to find relative contribution of input neuron
    rc = np.divide(abs(cw), abs(cw_h))
    rc = rc.sum(axis=1)

    # normalize to 100% for relative importance
    ri = rc / rc.sum()
    return(ri)

# %%
a_vector = np.reshape(regr.coefs_[1], -1)
a_vector
# Out:
# array([ 0.96130836, -0.25762851,  1.21140266])

# %%
garson(regr.coefs_[0], a_vector)
# Out:
# array([0.15965031, 0.13267481, 0.31597039, 0.09126212, 0.16475791,
#        0.13568446])

# %% [markdown]
# # Structure of ANN according to Yao et al. (1999) and Panahian (2011)

# %%
regr1 = MLPRegressor(hidden_layer_sizes=(2,),random_state=1, max_iter=500).fit(X_trainscaled, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
network_structure = np.hstack(([X_trainscaled.shape[1]], np.asarray(regr1.hidden_layer_sizes), [1]))

# %%
network=VisNN.DrawNN(network_structure, regr1.coefs_)
network.draw()

# %%
y_pred1 = regr1.predict(X_testscaled)
y_pred1
# Out:
# array([3.9712421 , 2.12280362, 1.57464678, 0.60873555, 0.5180665 ,
#        1.28713288, 1.55613629, 2.15855467, 3.40595959, 2.43705847,
#        4.48107177, 2.14349218, 3.44722562, 2.98050169, 2.44812485,
#        2.72326251, 3.0191259 , 4.19790829, 2.62093768, 2.87918538,
#        1.28713288, 3.25840673, 3.16100856, 1.50997697, 0.5180665 ,
#        2.11370134, 1.20210315, 2.62033651, 3.29973858, 4.45076805,
#        2.43705847, 3.49231492, 1.10486641, 2.5962015 , 1.78762455,
#        2.19581076, 1.96934522, 0.5180665 , 3.86881964, 4.30053285,
#        2.2867226 , 2.35107488, 2.2867226 , 2.70335   , 1.49926816,
#        2.0586466 , 1.01400145, 0.81317691, 2.9645118 , 3.56984587,
#        0.90404187, 3.18696578, 2.33544547, 3.14658226, 2.9645118 ,
#        2.22135641, 1.09315211, 4.56888371, 1.57142357, 2.19581076,
#        2.49056204, 3.40135337, 2.6917394 , 1.67872319, 0.99187648,
#        3.53148203, 3.28620931, 3.45319698, 2.52806952, 0.78270921,
# ...

# %%
df_temp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred1})
df_temp.head()
# Out:
#        Actual  Predicted
# 207  4.000000   3.971242
# 383  3.000000   2.122804
# 65   4.333333   1.574647
# 197  3.000000   0.608736
# 208  3.666667   0.518066

# %%
df_temp = df_temp.head(30)
df_temp.plot(kind='bar',figsize=(10,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred1))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred1))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))
# Out:
# Mean Absolute Error: 1.1668075454464495
# Mean Squared Error: 1.957217693079983
# Root Mean Squared Error: 1.3990059660630412

# %%
a_vector1 = np.reshape(regr1.coefs_[1], -1)
a_vector1
# Out:
# array([-1.13041149,  1.19108554])

# %%
garson(regr1.coefs_[0], a_vector1)
# Out:
# array([0.17946091, 0.18451713, 0.20843291, 0.08621515, 0.12842789,
#        0.21294601])
